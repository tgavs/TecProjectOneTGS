# %% [markdown]
# # 01 Data Wrangling

# %% [markdown]
# ## Build data frame with data from the IMSS open source files

# %% [markdown]
# In this workbook we will put wrap up the data bases from the IMSS ENSAT 2017,2018.
# The Objective is to build the data frame to analize the Satisfaction Surveys that the IMSS performs quarterly.

# %%
#Import Dependencies
import pandas as pd
import numpy as np
pd.options.display.max_seq_items = 2000
import requests
from fstrings import f

# %%
# Read all CSV files
# The original files comes in raw csv file with no encodign, so we have to save it into the origin as utf-8
df_abr_18=pd.read_csv('DataClean\Data\YR2018\Abr18.csv',encoding='utf-8')
df_jul_18=pd.read_csv('DataClean\Data\YR2018\Jul18.csv',encoding='utf-8')
df_nov_18=pd.read_csv('DataClean\Data\YR2018\\Nov18.csv',encoding='utf-8')
df_abr_17=pd.read_csv('DataClean\Data\YR2017\Abr17.csv',encoding='utf-8')
df_jun_17=pd.read_csv('DataClean\Data\YR2017\Jun17.csv',encoding='utf-8')
df_nov_17=pd.read_csv('DataClean\Data\YR2017\\Nov17.csv',encoding='utf-8')

# %%
#Build just one data frame that cointains all

dfall=pd.concat([df_nov_18,df_jul_18,df_abr_18,df_nov_17,df_jun_17,df_abr_17],sort=True)

# %%
dfall.columns
# Out:
# Index(['Amable', 'Antescita', 'Anticoncepe', 'Anticoncepp', 'Autortactop',
#        'Btratou', 'Btratou2', 'Btratou_Mot1', 'Btratou_Mot2', 'Btratou_Mot3',
#        'Calfatna_A', 'Calfatna_C', 'Calfatna_E', 'Calfatna_F', 'Calfatna_G',
#        'Calfatna_H', 'Calfatna_J', 'Calfatna_K', 'Calfatna_L', 'Calfatna_M',
#        'Calfatna_N', 'Calfatna_O', 'Calfatna_Q', 'Calfatnb_A', 'Calfatnb_C',
#        'Calfatnb_E', 'Calfatnb_F', 'Calfatnb_G', 'Calfatnb_H', 'Calfatnb_J',
#        'Calfatnb_K', 'Calfatnb_L', 'Calfatnb_M', 'Calfatnb_N', 'Calfatnb_O',
#        'Calfatnb_Q', 'Calfinmb_F', 'Califembp', 'Cartembe', 'Cartembp',
#        'Citapre', 'Comincomcons', 'Comocita', 'Comptmpunif', 'Comunincomp',
#        'Conocunifila', 'Consdesp', 'Cve_DelegacióN', 'Cve_Enc', 'Cve_Sup',
#        'Deleg', 'DelegacióN', 'Diascita', 'Dudasemb', 'Durasis_C', 'Edad',
#        'Edad_C', 'Entidad', 'Escolar', 'Escuchar', 'Estrato', 'Fe_Finalnr',
#        'Fecha', 'Fecha_A', 'Fecha_D', 'Fecha_M', 'Filtrofarm2', 'Filtroref',
#        'Filtrosaux1', 'Filtrosaux2', 'Filtrounifila', 'Folio', 'Gafet',
#        'Hr_Fin_H', 'Hr_Fin_M', 'Hr_Ini_H', 'Hr_Ini_M', 'Hrcita', 'Id_Unid',
#        'Id_Unidad', 'Infoedosaludp', 'Infomabbp', 'Infoportale', 'Infoportalp',
#        'Infoprocp', 'Infotourobse', 'Infotourobsp', 'Ingportale', 'Ingportalp',
#        'Limp1', 'Limp2', 'Local', 'Mejoratratou', 'Metdolor', 'Microzona',
#        'Moscondia', 'Motcalifembp1', 'Motcalifembp2', 'Motcalifembp3',
#        'Motcomunincomp1', 'Motcomunincomp2', 'Motcomunincomp3', 'Motivoant',
#        'Motnosurt', 'Mottratot1', 'Mottratot2', 'Mottratot3', 'Mottratot4',
#        'Mottratot5', 'Mottratot_1', 'Mottratot_2', 'Mottratot_3',
#        'Mottratot_4', 'Mottratot_5', 'Nivel', 'Noanticoncepe', 'Noanticoncepp',
#        'Ocupa', 'Portale', 'Portalp', 'Preosad', 'Presentp', 'Probsal',
#        'Promedio_Diario2016', 'Promedio_Diario2017', 'Proscesoref1',
#        'Proscesoref2', 'Proscesoref3', 'Proscesoref4', 'Proscesoref5',
#        'Proscesoref6', 'Proscesoref_1', 'Proscesoref_2', 'Proscesoref_3',
#        'Proscesoref_4', 'Proscesoref_5', 'Recmedhoy', 'Recomej_A', 'Recomej_B',
#        'Recomej_C', 'Responder', 'Saludar', 'Sat1', 'Sat1_Mot1', 'Sat1_Mot2',
#        'Sat1_Mot3', 'Sat3', 'Satiemesp', 'Satiemhoci', 'Satmedunif',
#        'Satprocref', 'Sattempref', 'Semambe', 'Servatn', 'Sexo', 'Tactop',
#        'Temsad1', 'Temsad1a', 'Temsad2', 'Temsad2a', 'Tiem_Esp1', 'Tiemuv',
#        'Tipodhu', 'Tipopac', 'Tlocal', 'Tmedreg2', 'Tmesphoci', 'Tmpespunif',
#        'Totmed', 'Totorpase1', 'Tourobse', 'Tourobsp', 'Tratocomf', 'Turno',
#        'Unidad', 'Unidmed', 'Utilcartembe', 'Utilcartembp'],
#       dtype='object')

# %%
unidades_medicas=dfall[['Unidmed','Entidad']]

# %%
# Extract unique Medical Unites
uniqueUMF=pd.DataFrame(dfall.groupby('Unidmed').Entidad.first())

# %%
uniqueUMF.reset_index(inplace=True)

uniqueUMF['Entidad']=uniqueUMF.Entidad.map({1:'Aguascalientes',
                                            2:'Baja California',
                                            3:'Baja California Sur',
                                            4:'Campeche',
                                            5:'Coahuila de Zaragoza',
                                            6:'Colima',
                                            7:'Chiapas',
                                            8:'Chihuahua',
                                            9:'Ciudad de México',
                                            10:'Durango',
                                            11:'Guanajuato',
                                            12:'Guerrero',
                                            13:'Hidalgo',
                                            14:'Jalisco',
                                            15:'Estado de México',
                                            16:'Michoacán de Ocampo',
                                            17:'Morelos',
                                            18:'Nayarit',
                                            19:'Nuevo León',
                                            20:'Oaxaca',
                                            21:'Puebla',
                                            22:'Querétaro',
                                            23:'Quintana Roo',
                                            24:'San Luis Potosí',
                                            25:'Sinaloa',
                                            26:'Sonora',
                                            27:'Tabasco',
                                            28:'Tamaulipas',
                                            29:'Tlaxcala',
                                            30:'Veracruz de Ignacio de la Llave',
                                            31:'Yucatán',
                                            32:'Zacatecas'
                                           })

uniqueUMF.head()
# Out:
#                  Unidmed           Entidad
# 0  HGOMF 60 Tlalnepantla  Estado de México
# 1   HGOMF 60 Tlanepantla  Estado de México
# 2        HGOMF 7 Tijuana   Baja California
# 3      HGPMF 31 Mexicali   Baja California
# 4     HGRMF 1 Cuernavaca           Morelos

# %%
UMFlist=uniqueUMF['Unidmed']
UMFentidad=uniqueUMF['Entidad']

# %% [markdown]
# # Geocoding Medical Units

# %%
# Medical Unit Geocoding Example

#Set the parameters
apikeyGoogleMaps='AIzaSyAYbCobeTOwvaE6tiwm6aikmBEpAitc8SQ'
unidad_med='UMFH 2 Benito Júarez'
entidad='Baja California Norte '
pais='México'
#Build url
url=f("https://maps.googleapis.com/maps/api/geocode/json?address=IMSS {unidad_med},{entidad},{pais}&key={apikeyGoogleMaps}")
print(url)
# Out:
# https://maps.googleapis.com/maps/api/geocode/json?address=IMSS UMFH 2 Benito Júarez,Baja California Norte ,México&key=AIzaSyAYbCobeTOwvaE6tiwm6aikmBEpAitc8SQ

# %%
# api call
unidad_med_response=requests.get(url)
location_json=unidad_med_response.json()

#display result
location_json
# Out:
# {'results': [{'address_components': [{'long_name': 'Poblado Licenciado Benito Juarez',
#      'short_name': 'Poblado Licenciado Benito Juarez',
#      'types': ['neighborhood', 'political']},
#     {'long_name': 'Mexicali',
#      'short_name': 'Mexicali',
#      'types': ['locality', 'political']},
#     {'long_name': 'Baja California',
#      'short_name': 'B.C.',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'Mexico',
#      'short_name': 'MX',
#      'types': ['country', 'political']},
#     {'long_name': '21900', 'short_name': '21900', 'types': ['postal_code']}],
#    'formatted_address': 'Av. Vicente Guerrero s/n, Poblado Licenciado Benito Juarez, 21900 Mexicali, B.C., Mexico',
#    'geometry': {'location': {'lat': 32.5686662, 'lng': -115.0001196},
#     'location_type': 'GEOMETRIC_CENTER',
#     'viewport': {'northeast': {'lat': 32.5700151802915,
#       'lng': -114.9987706197085},
#      'southwest': {'lat': 32.5673172197085, 'lng': -115.0014685802915}}},
#    'partial_match': True,
#    'place_id': 'ChIJxXkn5Tdx14ARg2Ku9PLQJIw',
#    'plus_code': {'compound_code': 'HX9X+FX Poblado Benito Juárez, Baja California, Mexico',
#     'global_code': '8546HX9X+FX'},
#    'types': ['establishment', 'health', 'point_of_interest']}],
#  'status': 'OK'}

# %%
#Json accesing example

location_json['results'][0]['address_components'][3]['long_name']
# Out:
# 'Mexico'

# %%
#list to gather information from the json responses
unidmedName=[]
lat=[]
lng=[]
address=[]
locality=[]
state=[]
notfound=[]

j=0 #counter for the log, does not interfere with the process just with the printing

total_records=str(len(UMFlist))

for umf,entidad in zip(UMFlist,UMFentidad):
   
    j= j+1

    try:
           
        #builds the url request for each UMF
        
        unidad_med=str(umf)
        pais='México'
        entidad=str(entidad)
        url=f("https://maps.googleapis.com/maps/api/geocode/json?address=IMSS {unidad_med},{entidad},{pais}&key={apikeyGoogleMaps}")
        
        print(f('{j} from {total_records}, searching {umf}'))
        
        print(f('{url}'))
        
        # Google maps api call
        
        unidad_med_response=requests.get(url)
        location_json=unidad_med_response.json()
        location_json
        
        #extract information from the json
             
        latitude=location_json['results'][0]['geometry']['location']['lat']
        longitude=location_json['results'][0]['geometry']['location']['lng']
        adress_explicit=location_json['results'][0]['formatted_address']
        local=location_json['results'][0]['address_components'][1]['long_name']
        stte=location_json['results'][0]['address_components'][2]['long_name']
                
        print(f('location: {umf}, status:found,lat:{latitude}, lng:{longitude}, adress:{adress_explicit}'))
               
        unidmedName.append(unidad_med)
        lat.append(latitude)
        lng.append(longitude)
        address.append(adress_explicit)
        locality.append(local)
        state.append(stte)
                    
    except:
        
        print(f('Location {umf} NOT FOUND...skipping'))
        
        unidmedName.append(np.nan)
        lat.append(np.nan)
        lng.append(np.nan)
        address.append(np.nan)
        locality.append(np.nan)
        state.append(np.nan)
        notfound.append(umf)
        
        pass
# Out:
# 1 from 1153, searching HGOMF 60 Tlalnepantla
# https://maps.googleapis.com/maps/api/geocode/json?address=IMSS H
# https://maps.googleapis.com/maps/api/geocode/json?address=IMSS HGZMF 1 Ciudad Victoria,Tamaulipas,México&key=AIzaSyAYbCobeTOwvaE6tiwm6aikmBEpAitc8SQ
# location: HGZMF 1 Ciudad Victoria, status:found,lat:23.7197073, lng:-99.14994399999999, adress:i m s s, Justo Sierra SN-S I.M.S.S, Centro Universitario, Cd Victoria, Tamps., Mexico
# 65 from 1153, searching HGZMF 1 Durango
# https://maps.googleapis.com/maps/api/geocode/json?address=IMSS HGZMF 1 Durango,Durango,México&key=AIzaSyAYbCobeTOwvaE6tiwm6aikmBEpAitc8SQ
# location: HGZMF 1 Durango, status:found,lat:24.0288786, lng:-104.6825264, adress:Predio Canoas SN, Dorador, 34070 Durango, Dgo., Mexico
# 66 from 1153, searching HGZMF 1 La Paz
# https://maps.googleapis.com/maps/api/geocode/json?address=IMSS HGZMF 1 La Paz,Baja California Sur,México&key=AIzaSyAYbCobeTOwvaE6tiwm6aikmBEpAitc8SQ
# location: HGZMF 1 La Paz, status:found,lat:24.1450595, lng:-110.3190432, adress:Calle V. Gómez Farias 2845, Pueblo Nuevo, 23060 La Paz, B.C.S., Mexico
# 67 from 1153, searching HGZMF 1 Pachuca
# https://maps.googleapis.com/maps/api/geocode/json?address=IMSS HGZMF 1 Pachuca,Hidalgo,México&key=AIzaSyAYbCobeTOwvaE6tiwm6aikmBEpAitc8SQ
# location: HGZMF 1 Pachuca, status:found,lat:20.1149991, lng:-98.7236842, adress:Av Francisco I. Madero 407, Nueva Francisco I Madero, Francisco I. Madero, 42070 Pachuca, Hgo., Mexico
# 68 from 1153, searching HGZMF 1 San Luis Potosí
# https://maps.googleapis.com/maps/api/geocode/json?address=IMSS HGZMF 1 San Luis Potosí,San Luis Potosí,México&key=AIzaSyAYbCobeTOwvaE6tiwm6aikmBEpAitc8SQ
# location: HGZMF 1 San Luis Potosí, status:found,lat:22.153893, lng:-100.9839902, adress:Avenida Nicolás Zapata 203, Centro, 78000 San Luis Potosí, SLP, Mexico
# 69 from 1153, searching HGZMF 1 Tapachula
# https://maps.googleapis.com/maps/api/geocode/json?address=IMSS HGZMF 1 Tapachula,Chiapas,México&key=AIzaSyAYbCobeTOwvaE6tiwm6aikmBEpAitc8SQ
# location: HGZMF 1 Tapachula, status:found,lat:14.9198264, lng:-92.26567460000001, adress:Coatancito 10, Los Naranjos, El Coatancito, 30700 Tapachula de Córdova y Ordoñez, Chis., Mexico
# 70 from 1153, searching HGZMF 10 Santiago Ixcuintla
# https://maps.googleapis.com/maps/api/geocode/json?address=IMSS HGZMF 10 Santiago Ixcuintla,Nayarit,México&key=AIzaSyAYbCobeTOwvaE6tiwm6aikmBEpAitc8SQ
# location: HGZMF 10 Santiago Ixcuintla, status:found,lat:21.8130101, lng:-105.1996444, adress:Netzahualcóyotl, López Velarde, 63311 Santiago Ixcuintla, Nay., Mexico
# 71 from 1153, searching HGZMF 11 Ciudad Delicias
# https://maps.googleapis.com/maps/api/geocode/json?address=IMSS HGZMF 11 Ciudad Delicias,Chihuahua,México&key=AIzaSyAYbCobeTOwvaE6tiwm6aikmBEpAitc8SQ
# location: HGZMF 11 Ciudad Delicias, status:found,lat:28.1950136, lng:-105.4780897, adress:Av. Río Conchos Pte. 515, Poniente, 33000 Delicias, Chih., Mexico
# 72 from 1153, searching HGZMF 12 Lázaro Cárdenas
# https://maps.googleapis.com/maps/api/geocode/json?address=IMSS HGZMF 12 Lázaro Cárdenas,Michoacán de Ocampo,México&key=AIzaSyAYbCobeTOwvaE6tiwm6aikmBEpAitc8SQ
# location: HGZMF 12 Lázaro Cárdenas, status:found,lat:17.9637455, lng:-102.1988475, adress:Av. Lázaro Cárdenas 154, 1er Sector de Fidelac, 60950 Lázaro Cárdenas, Mich., Mexico
# 73 from 1153, searching HGZMF 16 Ciudad Cuauhtémoc
# https://maps.googleapis.com/maps/api/geocode/json?address=IMSS HGZMF 16 Ciudad Cuauhtémoc,Chihuahua,México&key=AIzaSyAYbCobeTOwvaE6tiwm6aikmBEpAitc8SQ
# location: HGZMF 16 Ciudad Cuauhtémoc, status:found,lat:28.4063538, lng:-106.8487539, adress:16 de Sept., Progreso, 31550 Cd Cuauhtémoc, Chih., Mexico
# 74 from 1153, searching HGZMF 16 Torreón
# https://maps.googleapis.com/maps/api/geocode/json?address=IMSS HGZMF 16 Torreón,Coahuila de Zaragoza,México&key=AIzaSyAYbCobeTOwvaE6tiwm6aikmBEpAitc8SQ
# location: HGZMF 16 Torreón, status:found,lat:25.5354618, lng:-103.4458842, adress:Boulevard Revolución S/N, Luis Echeverría Álvarez Sector Norte, 27220 Torreón, Coah., Mexico
# 75 from 1153, searching HGZMF 18 Torreón
# https://maps.googleapis.com/maps/api/geocode/json?address=IMSS HGZMF 18 Torreón,Coahuila de Zaragoza,México&key=AIzaSyAYbCobeTOwvaE6tiwm6aikmBEpAitc8SQ
# location: HGZMF 18 Torreón, status:found,lat:25.5354618, lng:-103.4458842, adress:Boulevard Revolución S/N, Luis Echeverría Álvarez Sector Norte, 27220 Torreón, Coah., Mexico
# 76 from 1153, searching HGZMF 2 Apizaco
# https://maps.googleapis.com/maps/api/geocode/json?address=IMSS HGZMF 2 Apizaco,Tlaxcala,México&key=AIzaSyAYbCobeTOwvaE6tiwm6aikmBEpAitc8SQ
# location: HGZMF 2 Apizaco, status:found,lat:19.4102658, lng:-98.14966439999999, adress:San Martin de Porres, San Martín de Porres, 90337 Apizaco, Tlax., Mexico
# 77 from 1153, searching HGZMF 2 Irapuato
# https://maps.googleapis.com/maps/api/geocode/json?address=IMSS HGZMF 2 Irapuato,Guanajuato,México&key=AIzaSyAYbCobeTOwvaE6tiwm6aikmBEpAitc8SQ
# location: HGZMF 2 Irapuato, status:found,lat:20.6864628, lng:-101.3600584, adress:De La Reforma 307, Gamez, Viveros Revolucion, 36650 Irapuato, Gto., Mexico
# 78 from 1153, searching HGZMF 2 Monterrey
# https://maps.googleapis.com/maps/api/geocode/json?address=IMSS HGZMF 2 Monterrey,Nuevo León,México&key=AIzaSyAYbCobeTOwvaE6tiwm6aikmBEpAitc8SQ
# location: HGZMF 2 Monterrey, status:found,lat:25.6703789, lng:-100.2958524, adress:Obrera, Centro, 64010 Monterrey, N.L., Mexico
# 79 from 1153, searching HGZMF 2 Salina Cruz
# https://maps.googleapis.com/maps/api/geocode/json?address=IMSS HGZMF 2 Salina Cruz,Oaxaca,México&key=AIzaSyAYbCobeTOwvaE6tiwm6aikmBEpAitc8SQ
# location: HGZMF 2 Salina Cruz, status:found,lat:16.2021715, lng:-95.20171429999999, adress:Av. Nicolas Bravo 1, Hidalgo Oriente, 70610 Salina Cruz, Oax., Mexico
# 80 from 1153, searching HGZMF 2 Saltillo
# https://maps.googleapis.com/maps/api/geocode/json?address=IMSS HGZMF 2 Saltillo,Coahuila de Zaragoza,México&key=AIzaSyAYbCobeTOwvaE6tiwm6aikmBEpAitc8SQ
# location: HGZMF 2 Saltillo, status:found,lat:25.4538378, lng:-100.9864932, adress:Blvd. Venustiano Carranza 3458, El Kiosco, 25240 Saltillo, Coah., Mexico
# 81 from 1153, searching HGZMF 2 San Luis Potosí
# https://maps.googleapis.com/maps/api/geocode/json?address=IMSS HGZMF 2 San Luis Potosí,San Luis Potosí,México&key=AIzaSyAYbCobeTOwvaE6tiwm6aikmBEpAitc8SQ
# location: HGZMF 2 San Luis Potosí, status:found,lat:22.1481338, lng:-100.9873101, adress:Benigno Arriaga s/n, Tequisquiapan, 78250 San Luis, S.L.P., Mexico
# 82 from 1153, searching HGZMF 2 Zacapu
# https://maps.googleapis.com/maps/api/geocode/json?address=IMSS HGZMF 2 Zacapu,Michoacán de Ocampo,México&key=AIzaSyAYbCobeTOwvaE6tiwm6aikmBEpAitc8SQ
# location: HGZMF 2 Zacapu, status:found,lat:19.8143296, lng:-101.7823314, adress:Salvador Allende 100, Centro, 58600 Zacapu, Mich., Mexico
# 83 from 1153, searching HGZMF 20 Autlán de Navarro
# https://maps.googleapis.com/maps/api/geocode/json?address=IMSS HGZMF 20 Autlán de Navarro,Jalisco,México&key=AIzaSyAYbCobeTOwvaE6tiwm6aikmBEpAitc8SQ
# location: HGZMF 20 Autlán de Navarro, status:found,lat:19.7721578, lng:-104.36011, adress:Calle Jaime Llamas 5, Puerta de La Costa, 48900 Autlán de Navarro, Jal., Mexico
# 84 from 1153, searching HGZMF 21 León
# https://maps.googleapis.com/maps/api/geocode/json?address=IMSS HGZMF 21 León,Guanajuato,México&key=AIzaSyAYbCobeTOwvaE6tiwm6aikmBEpAitc8SQ
# location: HGZMF 21 León, status:found,lat:21.1086886, lng:-101.6879116, adress:Coral 101, Independencia, 37380 León, Gto., Mexico
# 85 from 1153, searching HGZMF 23 Hidalgo Parral
# https://maps.googleapis.com/maps/api/geocode/json?address=IMSS HGZMF 23 Hidalgo Parral,Chihuahua,México&key=AIzaSyAYbCobeTOwvaE6tiwm6aikmBEpAitc8SQ
# location: HGZMF 23 Hidalgo Parral, status:found,lat:26.9288583, lng:-105.6508589, adress:Sin Asignación En Nombre de Asentamiento, Hidalgo del Parral, Chih., Mexico
# 86 from 1153, searching HGZMF 24 Nueva Rosita
# https://maps.googleapis.com/maps/api/geocode/json?address=IMSS HGZMF 24 Nueva Rosita,Coahuila de Zaragoza,México&key=AIzaSyAYbCobeTOwvaE6tiwm6aikmBEpAitc8SQ
# location: HGZMF 24 Nueva Rosita, status:found,lat:27.9367303, lng:-101.2072187, adress:Del Maestro S/N, Col del Maestro, 26870 Nueva Rosita, Coah., Mexico
# 87 from 1153, searching HGZMF 26 Condesa
# https://maps.googleapis.com/maps/api/geocode/json?address=IMSS HGZMF 26 Condesa,Ciudad de México,México&key=AIzaSyAYbCobeTOwvaE6tiwm6aikmBEpAitc8SQ
# location: HGZMF 26 Condesa, status:found,lat:19.4078158, lng:-99.1692487, adress:Aguascalientes 159, Hipódromo, 06100 Ciudad de México, CDMX, Mexico
# 88 from 1153, searching HGZMF 26 Tala
# https://maps.googleapis.com/maps/api/geocode/json?address=IMSS HGZMF 26 Tala,Jalisco,México&key=AIzaSyAYbCobeTOwvaE6tiwm6aikmBEpAitc8SQ
# location: HGZMF 26 Tala, status:found,lat:20.652543, lng:-103.7080568, adress:Simon Bolívar 200, Rosal, 45300 Tala, Jal., Mexico
# 89 from 1153, searching HGZMF 28 Costa Rica
# https://maps.googleapis.com/maps/api/geocode/json?address=IMSS HGZMF 28 Costa Rica,Sinaloa,México&key=AIzaSyAYbCobeTOwvaE6tiwm6aikmBEpAitc8SQ
# location: HGZMF
Sinaloa,México&key=AIzaSyAYbCobeTOwvaE6tiwm6aikmBEpAitc8SQ
# location: UMFH 8 Mochicahui, status:found,lat:25.952865, lng:-108.931147, adress:Benito Juárez s/n, Mochicahui, Mochicahui, El Fuerte, Sin., Mexico
# 1147 from 1153, searching UMFH 8 Salvatierra
# https://maps.googleapis.com/maps/api/geocode/json?address=IMSS UMFH 8 Salvatierra,Guanajuato,México&key=AIzaSyAYbCobeTOwvaE6tiwm6aikmBEpAitc8SQ
# location: UMFH 8 Salvatierra, status:found,lat:20.2195621, lng:-100.8815274, adress:Juárez SN, Centro, 38900 Salvatierra, Gto., Mexico
# 1148 from 1153, searching UMFH 9 Luis B Sánchez
# https://maps.googleapis.com/maps/api/geocode/json?address=IMSS UMFH 9 Luis B Sánchez,Baja California,México&key=AIzaSyAYbCobeTOwvaE6tiwm6aikmBEpAitc8SQ
# location: UMFH 9 Luis B Sánchez, status:found,lat:32.19944400000001, lng:-114.995556, adress:Av Juarezy Kino N/A, Centro, 83500 San Luis Rio Colorado, Son., Mexico
# 1149 from 1153, searching UMFH 9 Luis B. Sánchez
# https://maps.googleapis.com/maps/api/geocode/json?address=IMSS UMFH 9 Luis B. Sánchez,Baja California,México&key=AIzaSyAYbCobeTOwvaE6tiwm6aikmBEpAitc8SQ
# location: UMFH 9 Luis B. Sánchez, status:found,lat:32.19944400000001, lng:-114.995556, adress:Av Juarezy Kino N/A, Centro, 83500 San Luis Rio Colorado, Son., Mexico
# 1150 from 1153, searching UMFH 9 Pénjamo
# https://maps.googleapis.com/maps/api/geocode/json?address=IMSS UMFH 9 Pénjamo,Guanajuato,México&key=AIzaSyAYbCobeTOwvaE6tiwm6aikmBEpAitc8SQ
# location: UMFH 9 Pénjamo, status:found,lat:20.4331951, lng:-101.7147705, adress:Santos Degollado 126, Palo Blanco, 36900 Pénjamo, Gto., Mexico
# 1151 from 1153, searching UMFH 9 Ruíz Cortínez
# https://maps.googleapis.com/maps/api/geocode/json?address=IMSS UMFH 9 Ruíz Cortínez,Sinaloa,México&key=AIzaSyAYbCobeTOwvaE6tiwm6aikmBEpAitc8SQ
# location: UMFH 9 Ruíz Cortínez, status:found,lat:25.7077466, lng:-108.7165359, adress:Adolfo Ruiz Cortinez, 81121 Adolfo Ruiz Cortines, Sin., Mexico
# 1152 from 1153, searching UMRM 21 Tamazulapan
# https://maps.googleapis.com/maps/api/geocode/json?address=IMSS UMRM 21 Tamazulapan,Oaxaca,México&key=AIzaSyAYbCobeTOwvaE6tiwm6aikmBEpAitc8SQ
# location: UMRM 21 Tamazulapan, status:found,lat:19.4235001, lng:-99.1732705, adress:Av. Paseo de la Reforma 476, Juárez, 06600 Ciudad de México, CDMX, Mexico
# 1153 from 1153, searching UMRM Ocampo
# https://maps.googleapis.com/maps/api/geocode/json?address=IMSS UMRM Ocampo,Coahuila de Zaragoza,México&key=AIzaSyAYbCobeTOwvaE6tiwm6aikmBEpAitc8SQ
# Location UMRM Ocampo NOT FOUND...skipping

# %%
#georeference data frame by UMF

geodf= pd.DataFrame({'Unidmed':unidmedName,
                     'lat':lat,
                     'lng':lng,
                     'address':address,
                     'locality':locality,
                   })

# %%
geodf.to_csv('DataClean\\UMFGecoding.csv',encoding='utf-8',index=False)

# %%
geodf.head()
# Out:
#                  Unidmed                                            address  \
# 0  HGOMF 60 Tlalnepantla  Av. Jose Maria Morelos 47, San Javier, 54000 T...
# 1   HGOMF 60 Tlanepantla  Av. Jose Maria Morelos 47, San Javier, 54000 T...
# 2        HGOMF 7 Tijuana              Aviación, 22420 Tijuana, B.C., Mexico
# 3      HGPMF 31 Mexicali  Avenida Sebastián Lerdo de Tejada s/n, Nueva, ...
# 4     HGRMF 1 Cuernavaca  Av. Plan de Ayala 1201, Chapultepec, 62450 Cue...
#
#          lat         lng               locality
# 0  19.539183  -99.190753           Tlalnepantla
# 1  19.539183  -99.190753           Tlalnepantla
# 2  32.514206 -117.009283                Tijuana
# 3  32.661990 -115.465917               Mexicali
# 4  18.922152  -99.205666  Avenida Plan de Ayala

# %%
df_merged=dfall.merge(geodf,how='left',on='Unidmed')

# %%
df_merged.head()
# Out:
#    Amable  Antescita  Anticoncepe  Anticoncepp  Autortactop  Btratou  \
# 0     1.0        1.0          1.0          NaN          NaN        2
# 1     1.0        1.0          NaN          NaN          NaN        2
# 2     1.0        1.0          NaN          NaN          NaN        1
# 3     1.0        1.0          NaN          NaN          NaN        1
# 4     1.0        1.0          NaN          NaN          NaN        2
#
#    Btratou2  Btratou_Mot1  Btratou_Mot2  Btratou_Mot3       ...        \
# 0       NaN           NaN           NaN           NaN       ...
# 1       NaN           NaN           NaN           NaN       ...
# 2       NaN           NaN           NaN           NaN       ...
# 3       NaN           NaN           NaN           NaN       ...
# 4       NaN           NaN           NaN           NaN       ...
#
#    Tratocomf  Turno                Unidad               Unidmed  Utilcartembe  \
# 0          2      1  UMF 1 Aguascalientes  UMF 1 Aguascalientes           1.0
# 1          2      1  UMF 1 Aguascalientes  UMF 1 Aguascalientes           NaN
# 2          2      1  UMF 1 Aguascalientes  UMF 1 Aguascalientes           NaN
# 3          2      1  UMF 1 Aguascalientes  UMF 1 Aguascalientes           NaN
# 4          2      1  UMF 1 Aguascalientes  UMF 1 Aguascalientes           NaN
#
#    Utilcartembp                                            address        lat  \
# 0           NaN  Blvd. Jose Maria Chavez 1202, Lindavista, 2027...  21.866007
# 1           NaN  Blvd. Jose Maria Chavez 1202, Lindavista, 2027...  21.866007
# 2           NaN  Blvd. Jose Maria Chavez 1202, Lindavista, 2027...  21.866007
# 3           NaN  Blvd. Jose Maria Chavez 1202, Lindavista, 2027...  21.866007
# 4           NaN  Blvd. Jose Maria Chavez 1202, Lindavista, 2027...  21.866007
#
#           lng        locality
# 0 -102.293548  Aguascalientes
# 1 -102.293548  Aguascalientes
# 2 -102.293548  Aguascalientes
# 3 -102.293548  Aguascalientes
# 4 -102.293548  Aguascalientes
#
# [5 rows x 182 columns]

# %%
#df=df.replace([99,995,998,999],np.nan)

#Replace entidad code by Name

df_merged['Entidad']=df_merged.Entidad.map({1:'Aguascalientes',
                                            2:'Baja California',
                                            3:'Baja California Sur',
                                            4:'Campeche',
                                            5:'Coahuila de Zaragoza',
                                            6:'Colima',
                                            7:'Chiapas',
                                            8:'Chihuahua',
                                            9:'Ciudad de México',
                                            10:'Durango',
                                            11:'Guanajuato',
                                            12:'Guerrero',
                                            13:'Hidalgo',
                                            14:'Jalisco',
                                            15:'Estado de México',
                                            16:'Michoacán de Ocampo',
                                            17:'Morelos',
                                            18:'Nayarit',
                                            19:'Nuevo León',
                                            20:'Oaxaca',
                                            21:'Puebla',
                                            22:'Querétaro',
                                            23:'Quintana Roo',
                                            24:'San Luis Potosí',
                                            25:'Sinaloa',
                                            26:'Sonora',
                                            27:'Tabasco',
                                            28:'Tamaulipas',
                                            29:'Tlaxcala',
                                            30:'Veracruz de Ignacio de la Llave',
                                            31:'Yucatán',
                                            32:'Zacatecas'
                                           })


#generate service type categorical value

df_merged['Servatn_cat']=df_merged.Servatn.map({1:'Consulta médica',
                                              2:'Medicina preventiva',
                                              3:'Consulta Dental'
                                              })

#generate patient type categorical value

df_merged['Tipopac_cat']=df_merged.Tipopac.map({1:'Mayor de edad',
                                              2:'Pediatrico',
                                              })
#generate satisfaction level categorical value

df_merged['Sat1_cat']=df_merged.Sat1.map({1:'Muy Satisfecho',
                                        2:'Satisfecho',
                                        3:'Ni satisfecho ni insatisfecho',
                                        4:'Insatisfecho',
                                        5:'Muy insatisfecho'
                                       })

#reorder satisfaction levels Satisfied with higher values insatisfied with lower values 
df_merged['Sat1_ordered']=df_merged.Sat1_cat.map({'Muy Satisfecho':5,
                                                'Satisfecho':4,
                                                'Ni satisfecho ni insatisfecho':3,
                                                'Insatisfecho':2,
                                                'Muy insatisfecho':1
                                               })


# Reson for Insatifaction categorical field
df_merged['Sat1_Mot1_cat']=df_merged.Sat1_Mot1.map({1:'Mal trato',
                                                  2:'Las instalaciones',
                                                  3:'Falta de medicamentos',
                                                  4:'Mal servicio en farmacia',
                                                  5:'Mal servicio en laboratorio',
                                                  6:'Mal servicio en archivo',
                                                  7:'Mal servicio de ambulancias',
                                                  8:'Los tiempos de espera para consulta',
                                                  9:'Los tiempos de espera para obtener citas',
                                                  10:'Los tiempos de espera para trámites',
                                                  11:'Los tiempos de espera para resultados de estudios',
                                                  12:'La falta de personal/médicos/especialistas',
                                                  13:'La limpieza en general de la unidad',
                                                  14:'Mala calidad en el servicio de urgencias',
                                                  15:'Mal servicio en general',
                                                  16:'Medicamentos de mala calidad',
                                                  17:'Faltan servicios médicos',
                                                  18:'Falta organización',
                                                  19:'Falta de recursos, materiales y equipo',
                                                  20:'Dan mal diagnóstico',
                                                  21:'Mala atención médica (no te revisan, no te explican lo que tienes)',
                                                  22:'Cambian a los médicos',
                                                  23:'Dan pocas fichas para consulta',
                                                  24:'Cancelan citas',
                                                  25:'Falta de comunicación entre el personal',
                                                  26:'No dan solución a problemas',
                                                  27:'Hay discriminación',
                                                  28:'Piden muchos trámites',
                                                  29:'El tiempo para cirugía es tardado',
                                                  30:'Mal servicio en rayos x',
                                                  31:'Mal servicio en especialidades',
                                                  33:'No dan incapacidad/ las incapacidades son cortas',
                                                  34:'Mal servicio en prevenimss',
                                                  35:'Hay sobrecupo de derechohabientes',
                                                  36:'Esperó mucho tiempo',
                                                  37:'Falta  de preparación del personal (médicos, enfermeras, etc.)',
                                                  38:'Mala atención del personal operativo, asistentes y enfermera',
                                                  39:'No se encuentra el personal',
                                                  40:'Mal servicio en viáticos',
                                                  41:'No respetan orden de llegada de pacientes',
                                                  42:'Quieren cobrar un servicio gratuito',
                                                  43:'Mal servicio de hospitalización',
                                                  44:'Mal servicio de unifila',
                                                  45:'No cumplen con el horario',
                                                  46:'Cancelan o cambian cirugía sin avisar',
                                                  47:'Por el horario de atención',
                                                  48:'Por cirugías mal realizadas',
                                                  50:'El servicio de dental debe mejorar',
                                                  52:'Por el cambio de clínica',
                                                  53:'Por la administración/ fallas administrativas',
                                                  55:'Negligencia médica',
                                                  56:'No pagan incapacidad/ pagan poco por la incapacidad',
                                                  57:'No explican bien/ falta de información/ mala información',
                                                  61:'Tardan en realizar estudios',
                                                  67:'No dan prioridad a casos urgentes',
                                                  70:'No cuentan con tratamiento para su padecimiento',
                                                  71:'No toman en cuenta su opinión',
                                                  73:'No dan atención especial a personas de la tercera edad / pacientes con discapacidad / pacientes vulnerables',
                                                  75:'Por tantas vueltas que hacen dar',
                                                  76:'No había sistema',
                                                  79:'Médicos familiares envian con otros médicos que no atienden',
                                                  81:'Le niegan el estudio que necesita',
                                                  82:'No dan suficiente medicamento',
                                                  83:'No funciona el internet para sacar citas',
                                                  86:'Mejorar el servicio a personas foráneas',
                                                  88:'El sistema no funciona bien',
                                                  89:'Le dieron incapacidad a fuerza',
                                                  90:'Lo cambian de consultorio',
                                                  91:'Lo enviaron a otra unidad',
                                                  92:'Es difícil llegar a la unidad',
                                                  93:'Siempre dan el mismo medicamento',
                                                  94:'Solicitó un comprobante para su trabajo y no se lo dieron',
                                                  95:'No hacen caso por estar con el celular',
                                                  96:'No dan pases a especialidades',
                                                  97:'Errores del personal (médicos, enfermeras, etc.)',
                                                  98:'No está conforme con los resultados',
                                                  99:'Mal servicio en trámites de pensión',
                                                  100:'Mal servicio en curaciones',
                                                  102:'Hay cosas que el seguro no cubre',
                                                  103:'Los traslados no se cumplen',
                                                  104:'No pudo dar de alta a su esposa',
                                                  105:'No le están dando el tratamiento completo',
                                                  106:'Atienden solo una enfermedad a la vez',
                                                  109:'No dejan pasar acompañantes o tienen que estar lejos',
                                                  111:'Solo dan citas espontáneas',
                                                  112:'Deben respetar creencias',
                                                  114:'Le enviaron a unifila',
                                                  116:'Inseguridad en las unidades médicas',
                                                  119:'Es difícil sacar citas por teléfono',
                                                  121:'Solo atienden bien cuando hay encuestadores',
                                                  123:'Le niegan el medicamento',
                                                  998:'Otro',
                                                  999:'No sabe/No responde'
                                                 })
# Health problem categorical field

df_merged['Probsal_cat']=df_merged.Probsal.map({1:'Embarazo',
                                                  2:'Seguimiento post parto o cesárea (Puerperio)',
                                                  3:'Enfermedades del corazón',
                                                  4:'Diabetes mellitus o pie diabético',
                                                  5:'Infecciones respiratorias agudas',
                                                  6:'Traumatismos y envenenamientos',
                                                  7:'Control, supervisión o seguimiento de personas sanas',
                                                  8:'Control o seguimiento del niño sano',
                                                  9:'Artropatías',
                                                  10:'Trastornos mentales y del comportamiento',
                                                  11:'Dorsopatías',
                                                  12:'Enfermedades de la piel y del tejido subcutáneo',
                                                  13:'Enfermedades Infecciosas Intestinales',
                                                  14:'Trastornos del metabolismo de las lipoproteínas y otras',
                                                  15:'Trastornos de los tejidos blandos',
                                                  16:'Rinitis, rinofaringitis y faringitis crónicas',
                                                  17:'Epilepsia',
                                                  18:'Infección de las vías urinarias',
                                                  19:'Bronquitis crónica y  la no especificada, enfisema y asma',
                                                  20:'Gastritis y duodenitis',
                                                  21:'Enfermedades de la glándula tiroides',
                                                  22:'Síndrome del colon irritable y otros trastornos funcionales',
                                                  23:'Desvanecimiento o desmayo repentino',
                                                  24:'Presencia de astenia o adinamia (debilidad, fatiga general o ausencia total de fuerza física)',
                                                  25:'Control de peso u obesidad',
                                                  26:'Hernia',
                                                  27:'Hipertensión',
                                                  28:'Absceso / Quistes',
                                                  29:'Accidente',
                                                  30:'Problemas del cerebro',
                                                  31:'Otorrinolaringología',
                                                  32:'Odontología',
                                                  33:'Alergia',
                                                  34:'Cirugías',
                                                  36:'Problemas en la sangre',
                                                  37:'Angeología',
                                                  38:'Planificación familiar',
                                                  39:'Oftalmología',
                                                  40:'Ácido úrico',
                                                  41:'Ginecología',
                                                  42:'Problemas en el estómago / Abdomen',
                                                  43:'Vacunas',
                                                  44:'Problemas en los pies / Piernas',
                                                  45:'Problemas en el pecho',
                                                  46:'Problemas pulmonares',
                                                  47:'Fiebre / Temperatura / Calentura',
                                                  48:'Cáncer / Leucemia',
                                                  49:'Tumor',
                                                  50:'Problemas de huesos',
                                                  51:'Problemas del riñon',
                                                  52:'Ciática / Nervio ciático',
                                                  53:'Pediatría',
                                                  54:'Próstata',
                                                  55:'Enfermedad general',
                                                  56:'Enfermedades del sistema nervioso',
                                                  57:'Dengue',
                                                  58:'Displasia',
                                                  59:'Problemas de cabeza (dolor, migraña, etc.)',
                                                  60:'Dolor en general',
                                                  61:'Problemas en mano o brazo',
                                                  62:'Problemas del aparato reproductor masculino',
                                                  63:'Problemas vesícula y vías biliares',
                                                  64:'Hemorragia',
                                                  65:'Reumatismo',
                                                  66:'Herpes',
                                                  67:'Enfermedad autoinmune',
                                                  68:'Fibromialgia',
                                                  69:'Ganglio',
                                                  70:'Infección bacteriana / Viral',
                                                  71:'Gastroenterología',
                                                  72:'Problemas del hígado',
                                                  73:'Inflamación / Hinchazón',
                                                  74:'Hiperplasia',
                                                  76:'Lupus',
                                                  78:'Problemas de aprendizaje o lenguaje',
                                                  79:'Maréo / vértigo',
                                                  80:'Moderdura / picadura de animal',
                                                  81:'Problemas de vejiga',
                                                  82:'Presión baja',
                                                  83:'Problemas hormonales',
                                                  85:'Úlcera',
                                                  86:'Varicela',
                                                  87:'Enfermedades de trasmisión sexual',
                                                  89:'Apéndice',
                                                  90:'Deshidratación',
                                                  91:'Hemorroides',
                                                  92:'Golpe de calor / insolación',
                                                  93:'Malformación congénita',
                                                  94:'Zika',
                                                  95:'Endocrinología',
                                                  96:'Tuberculosis',
                                                  99:'Enfermedad crónica',
                                                  100:'Geriatría',
                                                  101:'Retención de líquidos',
                                                  103:'Azúcar baja',
                                                  104:'Problemas de páncreas',
                                                  105:'Edema / retención de líquidos',
                                                  107:'Chikunguya',
                                                  108:'Discapacidad',
                                                  109:'Catéter',
                                                  110:'Medicina interna',
                                                  111:'Defensas bajas',
                                                  112:'Problemas del bazo',
                                                  113:'Chequeo de glucosa',
                                                  114:'Papanicolao',
                                                  115:'Tamiz',
                                                  116:'Seguimiento de cirugía',
                                                  999:'No sabe/No responde'
                                                 })

# %%
df_merged.columns
# Out:
# Index(['Amable', 'Antescita', 'Anticoncepe', 'Anticoncepp', 'Autortactop',
#        'Btratou', 'Btratou2', 'Btratou_Mot1', 'Btratou_Mot2', 'Btratou_Mot3',
#        'Calfatna_A', 'Calfatna_C', 'Calfatna_E', 'Calfatna_F', 'Calfatna_G',
#        'Calfatna_H', 'Calfatna_J', 'Calfatna_K', 'Calfatna_L', 'Calfatna_M',
#        'Calfatna_N', 'Calfatna_O', 'Calfatna_Q', 'Calfatnb_A', 'Calfatnb_C',
#        'Calfatnb_E', 'Calfatnb_F', 'Calfatnb_G', 'Calfatnb_H', 'Calfatnb_J',
#        'Calfatnb_K', 'Calfatnb_L', 'Calfatnb_M', 'Calfatnb_N', 'Calfatnb_O',
#        'Calfatnb_Q', 'Calfinmb_F', 'Califembp', 'Cartembe', 'Cartembp',
#        'Citapre', 'Comincomcons', 'Comocita', 'Comptmpunif', 'Comunincomp',
#        'Conocunifila', 'Consdesp', 'Cve_DelegacióN', 'Cve_Enc', 'Cve_Sup',
#        'Deleg', 'DelegacióN', 'Diascita', 'Dudasemb', 'Durasis_C', 'Edad',
#        'Edad_C', 'Entidad', 'Escolar', 'Escuchar', 'Estrato', 'Fe_Finalnr',
#        'Fecha', 'Fecha_A', 'Fecha_D', 'Fecha_M', 'Filtrofarm2', 'Filtroref',
#        'Filtrosaux1', 'Filtrosaux2', 'Filtrounifila', 'Folio', 'Gafet',
#        'Hr_Fin_H', 'Hr_Fin_M', 'Hr_Ini_H', 'Hr_Ini_M', 'Hrcita', 'Id_Unid',
#        'Id_Unidad', 'Infoedosaludp', 'Infomabbp', 'Infoportale', 'Infoportalp',
#        'Infoprocp', 'Infotourobse', 'Infotourobsp', 'Ingportale', 'Ingportalp',
#        'Limp1', 'Limp2', 'Local', 'Mejoratratou', 'Metdolor', 'Microzona',
#        'Moscondia', 'Motcalifembp1', 'Motcalifembp2', 'Motcalifembp3',
#        'Motcomunincomp1', 'Motcomunincomp2', 'Motcomunincomp3', 'Motivoant',
#        'Motnosurt', 'Mottratot1', 'Mottratot2', 'Mottratot3', 'Mottratot4',
#        'Mottratot5', 'Mottratot_1', 'Mottratot_2', 'Mottratot_3',
#        'Mottratot_4', 'Mottratot_5', 'Nivel', 'Noanticoncepe', 'Noanticoncepp',
#        'Ocupa', 'Portale', 'Portalp', 'Preosad', 'Presentp', 'Probsal',
#        'Promedio_Diario2016', 'Promedio_Diario2017', 'Proscesoref1',
#        'Proscesoref2', 'Proscesoref3', 'Proscesoref4', 'Proscesoref5',
#        'Proscesoref6', 'Proscesoref_1', 'Proscesoref_2', 'Proscesoref_3',
#        'Proscesoref_4', 'Proscesoref_5', 'Recmedhoy', 'Recomej_A', 'Recomej_B',
#        'Recomej_C', 'Responder', 'Saludar', 'Sat1', 'Sat1_Mot1', 'Sat1_Mot2',
#        'Sat1_Mot3', 'Sat3', 'Satiemesp', 'Satiemhoci', 'Satmedunif',
#        'Satprocref', 'Sattempref', 'Semambe', 'Servatn', 'Sexo', 'Tactop',
#        'Temsad1', 'Temsad1a', 'Temsad2', 'Temsad2a', 'Tiem_Esp1', 'Tiemuv',
#        'Tipodhu', 'Tipopac', 'Tlocal', 'Tmedreg2', 'Tmesphoci', 'Tmpespunif',
#        'Totmed', 'Totorpase1', 'Tourobse', 'Tourobsp', 'Tratocomf', 'Turno',
#        'Unidad', 'Unidmed', 'Utilcartembe', 'Utilcartembp', 'address', 'lat',
#        'lng', 'locality', 'Servatn_cat', 'Tipopac_cat', 'Sat1_cat',
#        'Sat1_ordered', 'Sat1_Mot1_cat', 'Probsal_cat'],
#       dtype='object')

# %%
# the less the time the appointment is required to happen it has a higher index puntuaction

df_merged['Diascita_ord']=df_merged.Diascita.map({1:'6',
                                                  2:'5',
                                                  3:'4',
                                                  4:'3',
                                                  5:'2',
                                                  6:'1',
                                                  99:np.nan})

df_merged['Citapre_ord']=df_merged.Citapre.map({1:1,
                                                2:0,
                                                99:np.nan})

# Punctual appointments have higher index values

df_merged['Hrcita_ord']=df_merged.Hrcita.map({1:3,
                                              2:2,
                                              3:1,
                                              99:np.nan})

#Lower waiting time hava higher index values

df_merged['Tmesphoci_ord']=df_merged.Tmesphoci.map({1:6,
                                                    2:5,
                                                    3:4,
                                                    4:3,
                                                    5:2,
                                                    6:1,
                                                    99:np.nan})

df_merged['Satiemhoci_ord']=df_merged.Satiemhoci.map({1:5,
                                                      2:4,
                                                      3:3,
                                                      4:2,
                                                      5:1,
                                                      99:np.nan})

# Lower wating times have higher index

df_merged['Tmedreg2_ord']=df_merged.Tmedreg2.map({1:6,
                                                  2:5,
                                                  3:4,
                                                  4:3,
                                                  5:2,
                                                  6:1,
                                                  99:np.nan})


df_merged['Satiemesp_ord']=df_merged.Satiemesp.map({1:5,
                                                    2:4,
                                                    3:3,
                                                    4:2,
                                                    5:1,
                                                    99:np.nan})

df_merged['Temsad1_ord']=df_merged.Temsad1.map({1:7,
                                                2:6,
                                                3:5,
                                                4:4,
                                                5:3,
                                                6:2,
                                                7:1,
                                                99:np.nan})

df_merged['Temsad2_ord']=df_merged.Temsad2.map({1:7,
                                                2:6,
                                                3:5,
                                                4:4,
                                                5:3,
                                                6:2,
                                                7:1,
                                                99:np.nan})

df_merged['Totmed_ord']=df_merged.Totmed.map({1:3,
                                              2:2,
                                              3:1,
                                              99:np.nan
                                              })


df_merged['Btratou_ord']=df_merged.Btratou.map({1:5,
                                                2:4,
                                                3:3,
                                                4:2,
                                                5:1,
                                                99:np.nan})


df_merged['Calfinmb_F_ord']=df_merged.Calfinmb_F.map({1:5,
                                                      2:4,
                                                      3:3,
                                                      4:2,
                                                      5:1,
                                                      99:np.nan})

# %%
# Create Date Field

df_merged['Date']=df_merged["Fecha_A"].map(str)+"-"+df_merged["Fecha_M"].map(str)+"-"+df_merged["Fecha_D"].map(str)

# %%
# Parse Date field as datetime object

df_merged['Date']=pd.to_datetime(df_merged['Date'])

# %%
#Export clean data csv file

df_merged.to_csv('DataClean\\NivelSatisf1Clean.csv',encoding='utf-8',index=False)
