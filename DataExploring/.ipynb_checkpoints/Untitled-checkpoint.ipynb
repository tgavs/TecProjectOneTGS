# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('D:\ENSATProyectoTecMtyBootCamp\DataClean\\NivelSatisf1.csv',encoding='utf-8')
# Out:
# D:\Anaconda\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_sat=dfall[['Folio',
                  'Deleg',
                  'Unidmed',
                  'Fecha_D',
                  'Fecha_M',
                  'Fecha_A',
                  'Servatn',
                  'Tipopac',
                  'Sat1',
                  'Sat1_Mot1',
                  'Sat1_Mot2',
                  'Sat1_Mot3',
                  'Sat3',
                  'Probsal']]

# %%
df.head()
# Out:
#    Folio  Deleg               Unidmed  Fecha_D  Fecha_M  Fecha_A  \
# 0   2001      1  UMF 1 Aguascalientes       31       10     2018
# 1   2002      1  UMF 1 Aguascalientes       31       10     2018
# 2   2003      1  UMF 1 Aguascalientes       31       10     2018
# 3   2004      1  UMF 1 Aguascalientes       31       10     2018
# 4   2005      1  UMF 1 Aguascalientes       31       10     2018
#
#            Servatn        Tipopac            Sat1 Sat1_Mot1  Sat1_Mot2  \
# 0  Consulta médica  Mayor de edad  Muy Satisfecho       NaN        NaN
# 1  Consulta médica  Mayor de edad      Satisfecho       NaN        NaN
# 2  Consulta médica  Mayor de edad  Muy Satisfecho       NaN        NaN
# 3  Consulta médica  Mayor de edad  Muy Satisfecho       NaN        NaN
# 4  Consulta médica  Mayor de edad  Muy Satisfecho       NaN        NaN
#
#    Sat1_Mot3  Sat3                            Probsal        lat         lng  \
# ...

# %%
df.shape
# Out:
# (232430, 17)

# %%
df.dtypes
# Out:
# Folio          int64
# Deleg          int64
# Unidmed       object
# Fecha_D        int64
# Fecha_M        int64
# Fecha_A        int64
# Servatn       object
# Tipopac       object
# Sat1          object
# Sat1_Mot1     object
# Sat1_Mot2    float64
# Sat1_Mot3    float64
# Sat3           int64
# Probsal       object
# lat          float64
# lng          float64
# address       object
# dtype: object

# %%
df.Sat1.value_counts()
# Out:
# Satisfecho                       159364
# Muy Satisfecho                    38654
# Insatisfecho                      16108
# Ni satisfecho ni insatisfecho     14205
# Muy insatisfecho                   3600
# Name: Sat1, dtype: int64

# %%
plt.figure(figsize=(15,6))
plt.xticks(rotation=90)
total = float(len(df.Sat1)) # one person per row 
ax = sns.countplot(x='Sat1', data=df,order = df.Sat1.value_counts().index) 
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,height + 1000,
            '{:1.2f}%'.format((height/total)*100),
            ha="center")
    
plt.title('Overall Satisfaction')
plt.ylabel('Response Count')
plt.xlabel('Level of Satisfaction')
plt.show()

# %%
df17=df[df['Fecha_A']==2017]

# %%
df18=df[df['Fecha_A']==2018]

# %%
plt.figure(figsize=(15,6))
plt.xticks(rotation=90)
total = float(len(df17.Sat1)) # one person per row 
ax1 = sns.countplot(x='Sat1', data=df17,order = df17.Sat1.value_counts().index) 
for p in ax1.patches:
    
    print(p)
    height = p.get_height()
    ax1.text(p.get_x()+p.get_width()/2.,height + 1000,
            '{:1.2f}%'.format((height/total)*100),
            ha="center")
    
plt.title('Overall Satisfaction 2017')
plt.ylabel('Response Count')
plt.xlabel('Level of Satisfaction')
plt.show()
# Out:
# Rectangle(xy=(-0.4, 0), width=0.8, height=74177, angle=0)
# Rectangle(xy=(0.6, 0), width=0.8, height=17629, angle=0)
# Rectangle(xy=(1.6, 0), width=0.8, height=8027, angle=0)
# Rectangle(xy=(2.6, 0), width=0.8, height=7568, angle=0)
# Rectangle(xy=(3.6, 0), width=0.8, height=1871, angle=0)

# %%
plt.figure(figsize=(15,6))
plt.xticks(rotation=90)
total = float(len(df18.Sat1)) # one person per row 
ax = sns.countplot(x='Sat1', data=df18,order = df18.Sat1.value_counts().index) 
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,height + 1000,
            '{:1.2f}%'.format((height/total)*100),
            ha="center")
    
plt.title('Overall Satisfaction 2018')
plt.ylabel('Response Count')
plt.xlabel('Level of Satisfaction')
plt.show()

# %%
df.head()
# Out:
#    Folio  Deleg               Unidmed  Fecha_D  Fecha_M  Fecha_A  \
# 0   2001      1  UMF 1 Aguascalientes       31       10     2018
# 1   2002      1  UMF 1 Aguascalientes       31       10     2018
# 2   2003      1  UMF 1 Aguascalientes       31       10     2018
# 3   2004      1  UMF 1 Aguascalientes       31       10     2018
# 4   2005      1  UMF 1 Aguascalientes       31       10     2018
#
#            Servatn        Tipopac            Sat1 Sat1_Mot1  Sat1_Mot2  \
# 0  Consulta médica  Mayor de edad  Muy Satisfecho       NaN        NaN
# 1  Consulta médica  Mayor de edad      Satisfecho       NaN        NaN
# 2  Consulta médica  Mayor de edad  Muy Satisfecho       NaN        NaN
# 3  Consulta médica  Mayor de edad  Muy Satisfecho       NaN        NaN
# 4  Consulta médica  Mayor de edad  Muy Satisfecho       NaN        NaN
#
#    Sat1_Mot3  Sat3                            Probsal        lat         lng  \
# ...

# %%
plt.figure(figsize=(8,25))
sns.countplot(y='Probsal',data=df,order = df.Probsal.value_counts().index)
plt.xlabel('Numero de encuestados')
plt.ylabel('Problema de Salud')
plt.title('Problema de Salud mencionados en las encuestas')
plt.show()

# %%
df.head()
# Out:
#    Folio  Deleg               Unidmed  Fecha_D  Fecha_M  Fecha_A  \
# 0   2001      1  UMF 1 Aguascalientes       31       10     2018
# 1   2002      1  UMF 1 Aguascalientes       31       10     2018
# 2   2003      1  UMF 1 Aguascalientes       31       10     2018
# 3   2004      1  UMF 1 Aguascalientes       31       10     2018
# 4   2005      1  UMF 1 Aguascalientes       31       10     2018
#
#            Servatn        Tipopac            Sat1 Sat1_Mot1  Sat1_Mot2  \
# 0  Consulta médica  Mayor de edad  Muy Satisfecho       NaN        NaN
# 1  Consulta médica  Mayor de edad      Satisfecho       NaN        NaN
# 2  Consulta médica  Mayor de edad  Muy Satisfecho       NaN        NaN
# 3  Consulta médica  Mayor de edad  Muy Satisfecho       NaN        NaN
# 4  Consulta médica  Mayor de edad  Muy Satisfecho       NaN        NaN
#
#    Sat1_Mot3  Sat3                            Probsal        lat         lng  \
# ...

# %%
satisfaction_per_site=pd.DataFrame(df.groupby('Unidmed').Sat1.value_counts())

# %%
sat_site=satisfaction_per_site.unstack()
sat_site.head()
# Out:
#                               Sat1                                  \
# Sat1                  Insatisfecho Muy Satisfecho Muy insatisfecho
# Unidmed
# HGOMF 60 Tlalnepantla         15.0           49.0              2.0
# HGOMF 60 Tlanepantla           9.0           15.0              2.0
# HGOMF 7 Tijuana               16.0          100.0              3.0
# HGPMF 31 Mexicali             11.0           98.0              4.0
# HGRMF 1 Cuernavaca            50.0          127.0             19.0
#
#
# Sat1                  Ni satisfecho ni insatisfecho Satisfecho
# Unidmed
# HGOMF 60 Tlalnepantla                           3.0      124.0
# HGOMF 60 Tlanepantla                            7.0       79.0
# HGOMF 7 Tijuana                                32.0      241.0
# HGPMF 31 Mexicali                              14.0      211.0
# HGRMF 1 Cuernavaca                             34.0      447.0

# %%
# Out:
#                                  Unidmed         Sat1                 \
# Sat1                                     Insatisfecho Muy Satisfecho
# 0                  HGOMF 60 Tlalnepantla         15.0           49.0
# 1                   HGOMF 60 Tlanepantla          9.0           15.0
# 2                        HGOMF 7 Tijuana         16.0          100.0
# 3                      HGPMF 31 Mexicali         11.0           98.0
# 4                     HGRMF 1 Cuernavaca         50.0          127.0
# 5               HGSMF 10 Sabinas Hidalgo          4.0           44.0
# 6                  HGSMF 11 Montemorelos          6.0           78.0
# 7                    HGSMF 12 Aguaprieta         27.0           47.0
# 8                       HGSMF 12 Linares         37.0           40.0
# 9                       HGSMF 12 Potrero          8.0           15.0
# 10                     HGSMF 13 Acámbaro         12.0            9.0
# 11                    HGSMF 15 Las Varas          3.0           31.0
# ...

# %%
# Out:
#                        Sat1                                               \
# Sat1                Unidmed Insatisfecho Muy Satisfecho Muy insatisfecho
# 0     HGOMF 60 Tlalnepantla         15.0           49.0              2.0
# 1      HGOMF 60 Tlanepantla          9.0           15.0              2.0
# 2           HGOMF 7 Tijuana         16.0          100.0              3.0
# 3         HGPMF 31 Mexicali         11.0           98.0              4.0
# 4        HGRMF 1 Cuernavaca         50.0          127.0             19.0
#
#
# Sat1 Ni satisfecho ni insatisfecho Satisfecho
# 0                              3.0      124.0
# 1                              7.0       79.0
# 2                             32.0      241.0
# 3                             14.0      211.0
# 4                             34.0      447.0

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-127-50badf3a2da1> in <module>()
# ----> 1 sat_site.reset_index(fill_level=0)
#
# TypeError: reset_index() got an unexpected keyword argument 'fill_level'
